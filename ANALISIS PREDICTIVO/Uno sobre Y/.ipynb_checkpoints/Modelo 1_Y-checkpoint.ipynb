# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv("C:/Users/HP/OneDrive - Universidad Tecnológica de Panamá/MAESTRIA EN ANALITICA DE DATOS/MODELOS PREDICTIVOS/proyecto gastos medicos - cambios del profesor/PROCESO DE CAMBIOS/Log Y/Dataset_Codificado_logy.csv")
df.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400     False        True             False
# 1   18  33.770         1   1725.55230      True       False             False
# 2   28  33.000         3   4449.46200      True       False             False
# 3   33  22.705         0  21984.47061      True       False              True
# 4   32  28.880         0   3866.85520      True       False              True
#
#    region_southeast  region_southwest     region      logy
# 0             False              True  Southwest  4.227499
# 1              True             False  Southeast  3.236928
# 2              True             False  Southeast  3.648308
# 3             False             False  Northwest  4.342116
# 4             False             False  Northwest  3.587358

# %%
#ANÁLISIS ESTADÍSTICO DE log (y)
# Estadísticos descriptivos
logy_stats = df[['logy']].describe().T
print("Estadísticos descriptivos para la variable 'logy':")
display(logy_stats)

# Moda
logy_mode = pd.DataFrame(df[['logy']].mode().iloc[0]).T
print("\nModa de la variable 'logy':")
display(logy_mode)

# Rango Intercuartílico (IQR)
logy_iqr = pd.DataFrame(df[['logy']].quantile(0.75) - df[['logy']].quantile(0.25)).T
logy_iqr.index = ['IQR']
print("\nRango Intercuartílico (IQR) de la variable 'logy':")
display(logy_iqr)
# Out:
# Estadísticos descriptivos para la variable 'logy':
#        count      mean       std       min       25%       50%       75%  \
# logy  1337.0  3.952048  0.398986  3.049944  3.676359  3.972488  4.221615
#
#            max
# logy  4.804619
# Moda de la variable 'logy':
#        logy
# 0  3.049944
# Rango Intercuartílico (IQR) de la variable 'logy':
#          logy
# IQR  0.545256

# %%
#### DISTRIBUCIÓN DE log(y)

col_num = ['logy']

for col in col_num:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribución de {col}')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
    plt.grid(True)
    plt.show()

# %%
#BOXPLOT

plt.figure(figsize=(15, 12))

plt.subplot(1, 1, 1)
sns.boxplot(data=df, y='logy', color='lightblue')
plt.title("Ln Y")

plt.tight_layout()
plt.show()

# %%
#### Análisis de Variabilidad (Coeficiente de Variación)

cv = df[col_num].std() / df[col_num].mean()
print("Coeficiente de Variación por variable numérica:")
print(cv.round(3))

#MAPA DE CALOR DE CORRELACIONES

plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Mapa de Calor de Correlaciones")
plt.tight_layout()
plt.show()
# Out:
# Coeficiente de Variación por variable numérica:
# logy    0.101
# dtype: float64

# %%
#Análisis de R² Individual (Regresión Simple)

#Para esto, hacemos una regresión lineal de charges con cada columna numérica por separado

for col in ['age', 'bmi', 'children']:
    X = df[[col]]
    y = df['logy']
    model = LinearRegression().fit(X, y)
    r2 = model.score(X, y)
    print(f'R² de logy ~ {col}: {r2:.4f}')
# Out:
# R² de logy ~ age: 0.2777
# R² de logy ~ bmi: 0.0176
# R² de logy ~ children: 0.0257

# %%
# BOXPLOTS

# Boxplot de logy según si fuma o no
plt.figure(figsize=(7, 4))
sns.boxplot(x='smoker_yes', y='logy', data=df)
plt.xticks([0, 1], ['No fumador', 'Fumador'])
plt.title("Log(y) según si es Fumador")
plt.xlabel("Fumador")
plt.ylabel("Log(y)")
plt.tight_layout()
plt.show()

# Boxplot de logy según el género
plt.figure(figsize=(7, 4))
sns.boxplot(x='sex_male', y='logy', data=df)
plt.xticks([0, 1], ['Mujer', 'Hombre'])
plt.title("logy según Género")
plt.xlabel("Sexo")
plt.ylabel("Log(y)")
plt.tight_layout()
plt.show()

# Boxplot según la región. Para ello recreamos la columna 'region'
region_columns = [col for col in df.columns if col.startswith('region_')]
region_map = {
    'region_northwest': 'Northwest',
    'region_southeast': 'Southeast',
    'region_southwest': 'Southwest'
}

df['region'] = 'Northeast'
for col in region_map:
    df.loc[df[col] == 1, 'region'] = region_map[col]

plt.figure(figsize=(8, 5))
sns.boxplot(x='region', y='logy', data=df)
plt.title("logy según Región")
plt.xlabel("Región")
plt.ylabel("Log(y)")
plt.tight_layout()
plt.show()

# %%
# VALOR DE R² PARA CADA VARIABLE CODIFICADA

binary_cols = ['sex_male', 'smoker_yes', 
               'region_northwest', 'region_southeast', 'region_southwest']

print("Correlación con log (y):")
for col in binary_cols:
    corr = df[col].astype(int).corr(df['logy'])  # Variable -> logy
    print(f"{col}: {corr:.4f}")

print("\nR² (Regresión lineal simple) con log (y):")
for col in binary_cols:
    X = df[[col]].astype(int)
    y = df['logy']  # Variable -> logy
    model = LinearRegression().fit(X, y)
    r2 = model.score(X, y)
    print(f"{col}: R² = {r2:.4f}")
# Out:
# Correlación con log (y):
# sex_male: 0.0070
# smoker_yes: 0.6657
# region_northwest: -0.0154
# region_southeast: 0.0150
# region_southwest: -0.0425
#
# R² (Regresión lineal simple) con log (y):
# sex_male: R² = 0.0000
# smoker_yes: R² = 0.4432
# region_northwest: R² = 0.0002
# region_southeast: R² = 0.0002
# region_southwest: R² = 0.0018

# %%
#SEPARAMOS NUESTRAS VARIABES X Y Y

#Eliminamos nuevamente la columna region, charges y lny  para definir nuestra X.
X = df.drop(['logy', 'region','charges'], axis=1)
y = df['logy']

# %%
#DIVIDIMOS NUESTRO CONJUNTO DE ENTRENAMIENTO Y PRUEBA usando CART

# Creamos y entrenamos el árbol de regresión (CART) para particionar los datos
tree_model = DecisionTreeRegressor(random_state=42)
tree_model.fit(X, y)

# Usamos el árbol para predecir y luego dividir según la predicción
y_pred_tree = tree_model.predict(X)

# Creamos una máscara para dividir el conjunto en entrenamiento y prueba (ejemplo: 80% con menor predicción del árbol)
threshold = np.percentile(y_pred_tree, 80)
train_mask = y_pred_tree <= threshold
test_mask = y_pred_tree > threshold

X_train, X_test = X[train_mask], X[test_mask]
y_train, y_test = y[train_mask], y[test_mask]

print("Tamaño del set de entrenamiento:", X_train.shape)
print("Tamaño del set de prueba:", X_test.shape)
# Out:
# Tamaño del set de entrenamiento: (1069, 8)
# Tamaño del set de prueba: (268, 8)

# %%
# ENTRENAMIENTO DEL MODELO XGBoost
model = LinearRegression()
model.fit(X_train, y_train)

# PREDICCIONES
y_pred = model.predict(X_test)

# EVALUACIÓN DEL MODELO
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred) * 100

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²: {r2:.4f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 0.29
# MSE: 0.13
# RMSE: 0.36
# R²: -7.3342
# MAPE: 6.54%

# %%
# VISUALIZACIÓN DE VALORES REALES VS VALORES DEL MODELO (PREDICCIÓN)

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], '--r')
plt.xlabel("Valores Reales (y_test)")
plt.ylabel("Valores Predichos (y_pred)")
plt.title("XGBOOST: Valores Reales vs Predichos")
plt.tight_layout()
plt.savefig("PRECISION REGRESION lineal LNY.png")
plt.show()

# %%
### GRÁFICO DE RESIDUOS

residuos = y_test - y_pred

plt.figure(figsize=(8, 5))
sns.histplot(residuos, kde=True, color='orange')
plt.title("Distribución de los Residuos")
plt.xlabel("Error (y_real - y_predicho)")
plt.tight_layout()
plt.savefig("RESIDUOS XGBOOST LNY.png")
plt.show()
